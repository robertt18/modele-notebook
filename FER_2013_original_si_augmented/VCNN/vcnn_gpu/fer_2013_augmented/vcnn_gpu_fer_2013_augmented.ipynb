# %%
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"Au fost detectate {len(gpus)} GPU-uri active:")
    for i, gpu in enumerate(gpus):
        print(f" Placa {i}: {gpu.name}")
else:
    print("Niciun GPU detectat. Sistemul rulează lent pe CPU.")
# Out:
# 2026-04-16 07:15:32.054367: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776323732.452507      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776323732.565120      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776323733.533114      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776323733.533153      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776323733.533157      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776323733.533160      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Au fost detectate 2 GPU-uri active:
#  Placa 0: /physical_device:GPU:0
#  Placa 1: /physical_device:GPU:1

# %%
strategy = tf.distribute.MirroredStrategy()
print(f"Numărul de unități grafice sincronizate: {strategy.num_replicas_in_sync}")
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Numărul de unități grafice sincronizate: 2
# I0000 00:00:1776323797.090637      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1776323797.096841      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
# celula 1 realizeaza preprocesarea datelor + augumentare
import keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir= '/kaggle/input/datasets/prilia/fer2013pluscleanedaugmballanced1/train'
test_dir='/kaggle/input/datasets/prilia/fer2013pluscleanedaugmballanced1/test'

print ("Versiune TensorFlow: ", tf.__version__)
print ("Versiune Keras: ", keras.__version__)

img_size=48
batch_size=64
epoci = 50
num_classes= 7 
print ("\n partea de preprocesare si impartire a datelor")
datagen = ImageDataGenerator (
    featurewise_center=False,
    featurewise_std_normalization=False,
    rescale=1./255,
    rotation_range=10,
    zoom_range= 0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.8,1.2],
    fill_mode='nearest',
    validation_split=0.20
)

test_datagen = ImageDataGenerator(rescale=1./255)

print("Setul de antrenare (80%):")
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    color_mode="grayscale",      
    batch_size=batch_size,
    class_mode='categorical',     
    shuffle=True                  
)

print("Setul de validare (20%):")
val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False,                
    subset='validation'           
)

print("Setul de testare:")
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_size, img_size),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Versiune TensorFlow:  2.19.0
# Versiune Keras:  3.10.0
#
#  partea de preprocesare si impartire a datelor
# Setul de antrenare (80%):
# Found 23251 images belonging to 7 classes.
# Setul de validare (20%):
# Found 4648 images belonging to 7 classes.
# Setul de testare:
# Found 5772 images belonging to 7 classes.

# %%
import os
import random
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array

clase_disponibile = os.listdir(train_dir)
clasa_random = random.choice(clase_disponibile)
folder_clasa = os.path.join(train_dir, clasa_random)

imagini_disponibile = os.listdir(folder_clasa)
imagine_random = random.choice(imagini_disponibile)
cale_imagine = os.path.join(folder_clasa, imagine_random)

img = load_img(cale_imagine, target_size=(img_size, img_size), color_mode="grayscale")
img_originala = img_to_array(img)

img_augmentata = datagen.random_transform(img_originala)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title(f"Original")

plt.imshow(img_originala.reshape(img_size, img_size), cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title("Augmentată")
plt.imshow(img_augmentata.reshape(img_size, img_size), cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
train_class_labels=train_generator.class_indices
print("etichete antrenament : ",train_class_labels)

val_class_labels=val_generator.class_indices
print("etichete validare : ",val_class_labels)

test_class_labels=test_generator.class_indices
print("etichete test : ",test_class_labels)
# Out:
# etichete antrenament :  {'Anger': 0, 'Disgust': 1, 'Fear': 2, 'Happy': 3, 'Neutral': 4, 'Sad': 5, 'Surprise': 6}
# etichete validare :  {'Anger': 0, 'Disgust': 1, 'Fear': 2, 'Happy': 3, 'Neutral': 4, 'Sad': 5, 'Surprise': 6}
# etichete test :  {'Anger': 0, 'Disgust': 1, 'Fear': 2, 'Happy': 3, 'Neutral': 4, 'Sad': 5, 'Surprise': 6}

# %%
#implementarea retelei de tip v-cnn 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input,Activation, BatchNormalization
from keras.optimizers import Adam 

def creare_v_cnn_model(input_shape, num_classes, flat=1, fil=[64,128,256], nl=[1,1,1], hid=[128]):
    model= Sequential()
    csize= 3; stri=2;
    psiz=2
    drop1=0.3

    model.add(Conv2D(fil[0],padding='same', kernel_size=(csize,csize),input_shape=input_shape))
    model.add(Activation('relu'))
    
    for i in range(nl[0]):
        model.add(Conv2D(fil[0], padding='same', kernel_size=(csize, csize)))
        model.add(Activation('relu'))

    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(psiz, psiz), strides=(stri, stri), padding='same'))
    model.add(Dropout(drop1))

    for layer in range(1, len(fil)):
        for j in range(nl[layer]):
            model.add(Conv2D(fil[layer], padding='same', kernel_size=(csize, csize)))
            model.add(Activation('relu'))
            
        model.add(BatchNormalization())
        model.add(MaxPooling2D(pool_size=(psiz, psiz), strides=(stri, stri), padding='same'))
        model.add(Dropout(drop1))

    if flat == 1:
        model.add(Flatten())
    else:
        model.add(GlobalAveragePooling2D())

    for h_size in hid:
        model.add(Dense(h_size, activation='relu'))
        model.add(Dropout(drop1))
    
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

print("Construim arhitectura V-CNN...")
with strategy.scope():
    model = creare_v_cnn_model(input_shape=(48, 48, 1), num_classes=7)

model.summary()
# Out:
# Construim arhitectura V-CNN...
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 48, 48, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │     1,179,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,589,063 (6.06 MB)
#  Trainable params: 1,588,167 (6.06 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint=ModelCheckpoint(
    "v_cnn_best_model.keras",
    monitor='val_accuracy', 
    verbose=1, 
    save_best_only=True, 
    mode='max'
)

early_stopping = EarlyStopping(
    monitor='val_accuracy', 
    patience=8,               
    restore_best_weights=True,
    verbose=1
)

# %%
import time

t_start_train = time.time()
istoric_antrenare= model.fit(
    train_generator,
    epochs=epoci,
    validation_data=val_generator,
    callbacks=[checkpoint,early_stopping]
)
t_end_train = time.time()

t_start_test = time.time()
score=model.evaluate(test_generator, verbose=0)
t_end_test = time.time()

nr_total_poze= test_generator.samples

timp_antrenament_minute = int(t_end_train - t_start_train) / 60
timp_testare_secunde = t_end_test - t_start_test
latenta_ms = 1000 * timp_testare_secunde / nr_total_poze

epoci_rulate = len(istoric_antrenare.history['loss'])

print(' RAPORT DE PERFORMANȚĂ V-CNN')

print(f'Timp total antrenament ({epoci_rulate} epoci): {timp_antrenament_minute:.2f} minute')
print(f'Numărul total de parametri: {model.count_params()}')
print(f'Acuratețea finală pe setul de test: {score[1]*100:.2f} %')
print(f'Timpul total de predicție la test: {timp_testare_secunde:.4f} secunde')
print(f'Latența pe GPU (per cadru): {latenta_ms:.4f} ms')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 18 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# E0000 00:00:1776323865.808216      55 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/sequential_1_1/dropout_4_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# I0000 00:00:1776323866.839409     127 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1776323867.814937     126 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.1844 - loss: 2.3362INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
#
# Epoch 1: val_accuracy improved from -inf to 0.18524, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 108s 274ms/step - accuracy: 0.1845 - loss: 2.3352 - val_accuracy: 0.1852 - val_loss: 1.9189
# Epoch 2/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3022 - loss: 1.6845
# Epoch 2: val_accuracy improved from 0.18524 to 0.38188, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 48s 132ms/step - accuracy: 0.3022 - loss: 1.6844 - val_accuracy: 0.3819 - val_loss: 1.5497
# Epoch 3/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.3603 - loss: 1.5311
# Epoch 3: val_accuracy did not improve from 0.38188
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 47s 130ms/step - accuracy: 0.3603 - loss: 1.5311 - val_accuracy: 0.3281 - val_loss: 2.4522
# Epoch 4/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.3857 - loss: 1.4867
# Epoch 4: val_accuracy improved from 0.38188 to 0.47268, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 47s 129ms/step - accuracy: 0.3857 - loss: 1.4867 - val_accuracy: 0.4727 - val_loss: 1.2837
# Epoch 5/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.4105 - loss: 1.4151
# Epoch 5: val_accuracy did not improve from 0.47268
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 47s 128ms/step - accuracy: 0.4105 - loss: 1.4151 - val_accuracy: 0.3782 - val_loss: 2.1499
# Epoch 6/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4275 - loss: 1.3845
# Epoch 6: val_accuracy did not improve from 0.47268
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 49s 134ms/step - accuracy: 0.4276 - loss: 1.3845 - val_accuracy: 0.4636 - val_loss: 1.3751
# Epoch 7/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4322 - loss: 1.3596
# Epoch 7: val_accuracy improved from 0.47268 to 0.51700, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 50s 138ms/step - accuracy: 0.4322 - loss: 1.3595 - val_accuracy: 0.5170 - val_loss: 1.2424
# Epoch 8/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.4579 - loss: 1.3141
# Epoch 8: val_accuracy improved from 0.51700 to 0.53098, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 51s 140ms/step - accuracy: 0.4579 - loss: 1.3141 - val_accuracy: 0.5310 - val_loss: 1.1903
# Epoch 9/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.4844 - loss: 1.2691
# Epoch 9: val_accuracy improved from 0.53098 to 0.58907, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 51s 141ms/step - accuracy: 0.4844 - loss: 1.2692 - val_accuracy: 0.5891 - val_loss: 1.0752
# Epoch 10/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5041 - loss: 1.2285
# Epoch 10: val_accuracy did not improve from 0.58907
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 52s 141ms/step - accuracy: 0.5041 - loss: 1.2285 - val_accuracy: 0.4385 - val_loss: 1.4644
# Epoch 11/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5264 - loss: 1.1803
# Epoch 11: val_accuracy improved from 0.58907 to 0.65297, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 51s 140ms/step - accuracy: 0.5264 - loss: 1.1803 - val_accuracy: 0.6530 - val_loss: 0.9262
# Epoch 12/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5443 - loss: 1.1544
# Epoch 12: val_accuracy did not improve from 0.65297
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 48s 131ms/step - accuracy: 0.5443 - loss: 1.1544 - val_accuracy: 0.6147 - val_loss: 1.0140
# Epoch 13/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5523 - loss: 1.1302
# Epoch 13: val_accuracy improved from 0.65297 to 0.65878, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 49s 135ms/step - accuracy: 0.5524 - loss: 1.1302 - val_accuracy: 0.6588 - val_loss: 0.9561
# Epoch 14/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5631 - loss: 1.1181
# Epoch 14: val_accuracy improved from 0.65878 to 0.67836, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 49s 135ms/step - accuracy: 0.5631 - loss: 1.1181 - val_accuracy: 0.6784 - val_loss: 0.8194
# Epoch 15/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5830 - loss: 1.0775
# Epoch 15: val_accuracy improved from 0.67836 to 0.69578, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 49s 133ms/step - accuracy: 0.5830 - loss: 1.0775 - val_accuracy: 0.6958 - val_loss: 0.8037
# Epoch 16/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5950 - loss: 1.0535
# Epoch 16: val_accuracy improved from 0.69578 to 0.71127, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 50s 136ms/step - accuracy: 0.5950 - loss: 1.0534 - val_accuracy: 0.7113 - val_loss: 0.7712
# Epoch 17/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6112 - loss: 1.0163
# Epoch 17: val_accuracy did not improve from 0.71127
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 49s 133ms/step - accuracy: 0.6112 - loss: 1.0163 - val_accuracy: 0.6661 - val_loss: 0.8820
# Epoch 18/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6181 - loss: 1.0132
# Epoch 18: val_accuracy did not improve from 0.71127
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 49s 135ms/step - accuracy: 0.6181 - loss: 1.0132 - val_accuracy: 0.6941 - val_loss: 0.8247
# Epoch 19/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.6241 - loss: 0.9912
# Epoch 19: val_accuracy improved from 0.71127 to 0.71794, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 48s 132ms/step - accuracy: 0.6241 - loss: 0.9911 - val_accuracy: 0.7179 - val_loss: 0.7753
# Epoch 20/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.6348 - loss: 0.9728
# Epoch 20: val_accuracy improved from 0.71794 to 0.73128, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 47s 130ms/step - accuracy: 0.6348 - loss: 0.9728 - val_accuracy: 0.7313 - val_loss: 0.7564
# Epoch 21/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.6350 - loss: 0.9643
# Epoch 21: val_accuracy improved from 0.73128 to 0.73817, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 48s 132ms/step - accuracy: 0.6351 - loss: 0.9643 - val_accuracy: 0.7382 - val_loss: 0.7031
# Epoch 22/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.6415 - loss: 0.9641
# Epoch 22: val_accuracy did not improve from 0.73817
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 47s 129ms/step - accuracy: 0.6415 - loss: 0.9641 - val_accuracy: 0.6863 - val_loss: 0.8458
# Epoch 23/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.6530 - loss: 0.9320
# Epoch 23: val_accuracy did not improve from 0.73817
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 47s 129ms/step - accuracy: 0.6530 - loss: 0.9320 - val_accuracy: 0.6870 - val_loss: 0.8379
# Epoch 24/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.6591 - loss: 0.9150
# Epoch 24: val_accuracy did not improve from 0.73817
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 47s 130ms/step - accuracy: 0.6591 - loss: 0.9150 - val_accuracy: 0.7317 - val_loss: 0.7418
# Epoch 25/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.6719 - loss: 0.8963
# Epoch 25: val_accuracy improved from 0.73817 to 0.74785, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 47s 128ms/step - accuracy: 0.6719 - loss: 0.8963 - val_accuracy: 0.7478 - val_loss: 0.7081
# Epoch 26/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.6600 - loss: 0.9144
# Epoch 26: val_accuracy did not improve from 0.74785
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 46s 126ms/step - accuracy: 0.6600 - loss: 0.9144 - val_accuracy: 0.7405 - val_loss: 0.6907
# Epoch 27/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.6726 - loss: 0.8931
# Epoch 27: val_accuracy did not improve from 0.74785
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 48s 131ms/step - accuracy: 0.6726 - loss: 0.8930 - val_accuracy: 0.7470 - val_loss: 0.7278
# Epoch 28/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.6843 - loss: 0.8617
# Epoch 28: val_accuracy improved from 0.74785 to 0.78421, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 48s 131ms/step - accuracy: 0.6843 - loss: 0.8618 - val_accuracy: 0.7842 - val_loss: 0.5799
# Epoch 29/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.6851 - loss: 0.8547
# Epoch 29: val_accuracy did not improve from 0.78421
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 47s 129ms/step - accuracy: 0.6851 - loss: 0.8547 - val_accuracy: 0.7694 - val_loss: 0.6324
# Epoch 30/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.6902 - loss: 0.8513
# Epoch 30: val_accuracy did not improve from 0.78421
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 47s 128ms/step - accuracy: 0.6902 - loss: 0.8513 - val_accuracy: 0.7106 - val_loss: 0.7968
# Epoch 31/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.6836 - loss: 0.8496
# Epoch 31: val_accuracy improved from 0.78421 to 0.79131, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 47s 130ms/step - accuracy: 0.6836 - loss: 0.8496 - val_accuracy: 0.7913 - val_loss: 0.5811
# Epoch 32/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6970 - loss: 0.8202
# Epoch 32: val_accuracy did not improve from 0.79131
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 49s 134ms/step - accuracy: 0.6970 - loss: 0.8202 - val_accuracy: 0.7840 - val_loss: 0.6023
# Epoch 33/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.7002 - loss: 0.8117
# Epoch 33: val_accuracy did not improve from 0.79131
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 48s 132ms/step - accuracy: 0.7002 - loss: 0.8117 - val_accuracy: 0.7808 - val_loss: 0.5966
# Epoch 34/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.7051 - loss: 0.8013
# Epoch 34: val_accuracy improved from 0.79131 to 0.79970, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 49s 133ms/step - accuracy: 0.7051 - loss: 0.8013 - val_accuracy: 0.7997 - val_loss: 0.5733
# Epoch 35/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.7096 - loss: 0.7909
# Epoch 35: val_accuracy improved from 0.79970 to 0.80572, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 48s 132ms/step - accuracy: 0.7096 - loss: 0.7910 - val_accuracy: 0.8057 - val_loss: 0.5219
# Epoch 36/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.7058 - loss: 0.7906
# Epoch 36: val_accuracy did not improve from 0.80572
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 48s 131ms/step - accuracy: 0.7058 - loss: 0.7906 - val_accuracy: 0.6984 - val_loss: 0.9148
# Epoch 37/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.7178 - loss: 0.7787
# Epoch 37: val_accuracy did not improve from 0.80572
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 48s 130ms/step - accuracy: 0.7178 - loss: 0.7787 - val_accuracy: 0.8014 - val_loss: 0.5253
# Epoch 38/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.7042 - loss: 0.8018
# Epoch 38: val_accuracy did not improve from 0.80572
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 48s 129ms/step - accuracy: 0.7042 - loss: 0.8018 - val_accuracy: 0.7943 - val_loss: 0.5779
# Epoch 39/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.7164 - loss: 0.7817
# Epoch 39: val_accuracy did not improve from 0.80572
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 47s 129ms/step - accuracy: 0.7164 - loss: 0.7817 - val_accuracy: 0.7778 - val_loss: 0.5789
# Epoch 40/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.7151 - loss: 0.7794
# Epoch 40: val_accuracy did not improve from 0.80572
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 47s 129ms/step - accuracy: 0.7151 - loss: 0.7794 - val_accuracy: 0.7898 - val_loss: 0.5976
# Epoch 41/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.7121 - loss: 0.7818
# Epoch 41: val_accuracy did not improve from 0.80572
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 48s 132ms/step - accuracy: 0.7122 - loss: 0.7817 - val_accuracy: 0.8025 - val_loss: 0.5281
# Epoch 42/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7250 - loss: 0.7617
# Epoch 42: val_accuracy did not improve from 0.80572
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 49s 134ms/step - accuracy: 0.7250 - loss: 0.7617 - val_accuracy: 0.6949 - val_loss: 1.0895
# Epoch 43/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7231 - loss: 0.7631
# Epoch 43: val_accuracy did not improve from 0.80572
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 49s 133ms/step - accuracy: 0.7232 - loss: 0.7630 - val_accuracy: 0.7956 - val_loss: 0.5365
# Epoch 43: early stopping
# Restoring model weights from the end of the best epoch: 35.
#  RAPORT DE PERFORMANȚĂ V-CNN
# Timp total antrenament (43 epoci): 35.62 minute
# Numărul total de parametri: 1589063
# Acuratețea finală pe setul de test: 76.54 %
# Timpul total de predicție la test: 27.2692 secunde
# Latența pe GPU (per cadru): 4.7244 ms

# %%
from tensorflow.keras.models import load_model
model = load_model('v_cnn_best_model.keras')

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

test_generator.reset()

print("Calculăm predicțiile pe setul de test...")
y_pred_probs = model.predict(test_generator, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_generator.classes

etichete = list(test_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='PuRd', 
            xticklabels=etichete, yticklabels=etichete)
plt.title('Matricea de Confuzie - Model V-CNN Final')
plt.ylabel('Emoție Reală')
plt.xlabel('Emoție Prezisă')
plt.show()

print("\nRaport de Clasificare Detaliat:\n")
print(classification_report(y_true, y_pred, target_names=etichete, zero_division=0))
# Out:
# Calculăm predicțiile pe setul de test...
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step
# Raport de Clasificare Detaliat:
#
#               precision    recall  f1-score   support
#
#        angry       0.45      0.59      0.51       958
#      disgust       0.00      0.00      0.00       111
#         fear       0.44      0.20      0.27      1024
#        happy       0.85      0.85      0.85      1774
#      neutral       0.56      0.62      0.58      1233
#          sad       0.44      0.47      0.46      1247
#     surprise       0.68      0.81      0.74       831
#
#     accuracy                           0.60      7178
#    macro avg       0.49      0.51      0.49      7178
# weighted avg       0.59      0.60      0.58      7178

# %%
import matplotlib.pyplot as plt


acc = istoric_antrenare.history['accuracy']
val_acc = istoric_antrenare.history['val_accuracy']
loss = istoric_antrenare.history['loss']
val_loss = istoric_antrenare.history['val_loss']

epoci_rulate = range(1, len(acc) + 1)


plt.figure(figsize=(14, 5))


plt.subplot(1, 2, 1)
plt.plot(epoci_rulate, acc, 'b-', linewidth=2, label='Antrenament')
plt.plot(epoci_rulate, val_acc, 'r-', linewidth=2, label='Validare')
plt.title('Evoluția Acurateții V-CNN', fontsize=14)
plt.xlabel('Număr Epoci', fontsize=12)
plt.ylabel('Acuratețe', fontsize=12)
plt.legend(loc='lower right')
plt.grid(True, linestyle='--', alpha=0.7)


plt.subplot(1, 2, 2)
plt.plot(epoci_rulate, loss, 'b-', linewidth=2, label='Eroare Antrenament')
plt.plot(epoci_rulate, val_loss, 'r-', linewidth=2, label='Eroare Validare')
plt.title('Scăderea Erorii (Loss) V-CNN', fontsize=14)
plt.xlabel('Număr Epoci', fontsize=12)
plt.ylabel('Valoare Eroare', fontsize=12)
plt.legend(loc='upper right')
plt.grid(True, linestyle='--', alpha=0.7)


plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

def testeaza_cu_legenda(cale_imagine):
    
    etichete_en = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
    
    clase_ro = {
        'angry': 'FURIE',
        'disgust': 'DEZGUST',
        'fear': 'FRICĂ',
        'happy': 'FERICIRE',
        'neutral': 'NEUTRU',
        'sad': 'TRISTEȚE',
        'surprise': 'SURPRIZĂ'
    }
    
    nume_ro_scurt = ['Furie', 'Dezgust', 'Frică', 'Fericire', 'Neutru', 'Tristețe', 'Surpriză']

    try:
        img_pt_model = image.load_img(cale_imagine, target_size=(48, 48), color_mode="grayscale")
    except Exception as e:
        print(f"Eroare la încărcarea imaginii: {e}")
        return

    img_array = image.img_to_array(img_pt_model)
    img_array = np.expand_dims(img_array, axis=0) 
    img_array /= 255.0 

    predictii_brute = model.predict(img_array)[0] 
    index_maxim = np.argmax(predictii_brute)
    
    emotie_w_en = etichete_en[index_maxim]
    emotie_w_ro = clase_ro[emotie_w_en]
    procent_w = predictii_brute[index_maxim] * 100

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
    
    img_orig = cv2.imread(cale_imagine)
    if img_orig is None:
        print("Eroare: Nu am putut citi imaginea originală pentru afișare!")
        return
    img_orig = cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB)
    
    ax1.imshow(img_orig)
    ax1.axis('off') 
    
    culoare_titlu = 'green' if emotie_w_en == 'happy' else 'red' if emotie_w_en in ['angry', 'fear'] else 'darkblue'
    
    ax1.set_title(f"Rețeaua V-CNN prezice:\n{emotie_w_ro} ({procent_w:.2f}%)", 
                  fontsize=18, color=culoare_titlu, fontweight='bold', pad=20)

    y_pos = np.arange(len(nume_ro_scurt))
    procente_afisare = predictii_brute * 100
    
    bare = ax2.barh(y_pos, procente_afisare, align='center', color='skyblue', alpha=0.8)
    
    bare[index_maxim].set_color('deeppink')
    bare[index_maxim].set_alpha(1.0)

    ax2.set_yticks(y_pos)
    ax2.set_yticklabels(nume_ro_scurt, fontsize=12)
    ax2.invert_yaxis() 
    ax2.set_xlabel('Probabilitate (%)', fontsize=12)
    ax2.set_title('Distribuția detaliată a probabilităților', fontsize=14, pad=15)
    
    for i, bar in enumerate(bare):
        latime = bar.get_width()
        ax2.text(latime + 1, bar.get_y() + bar.get_height()/2, 
                 f'{procente_afisare[i]:.1f}%', 
                 va='center', fontsize=10, fontweight='bold' if i == index_maxim else 'normal')

    ax2.set_xlim(0, 110) 
    ax2.grid(axis='x', linestyle='--', alpha=0.5)

    plt.tight_layout()
    plt.show()


testeaza_cu_legenda('/kaggle/input/datasets/msambare/fer2013/test/fear/PrivateTest_14639804.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step

# %%
from tensorflow.keras.models import load_model

cale_model = '/kaggle/input/datasets/mindrocrobert/modelulmeu/v_cnn_best_model (1).keras'
model = load_model(cale_model)

print("✅ SUCCES: Modelul este acum încărcat în memorie!")
# Out:
# ✅ SUCCES: Modelul este acum încărcat în memorie!
