# %%
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"Au fost detectate {len(gpus)} GPU-uri active:")
    for i, gpu in enumerate(gpus):
        print(f" Placa {i}: {gpu.name}")
else:
    print("Niciun GPU detectat. Sistemul rulează lent pe CPU.")
# Out:
# 2026-04-16 11:14:45.333249: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776338085.523561      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776338085.576242      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776338086.044047      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776338086.044097      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776338086.044099      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776338086.044102      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Au fost detectate 2 GPU-uri active:
#  Placa 0: /physical_device:GPU:0
#  Placa 1: /physical_device:GPU:1

# %%
strategy = tf.distribute.MirroredStrategy()
print(f"Numărul de unități grafice sincronizate: {strategy.num_replicas_in_sync}")
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Numărul de unități grafice sincronizate: 2
# I0000 00:00:1776338120.452455      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1776338120.458353      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
# celula 1 realizeaza preprocesarea datelor + augumentare
import keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir= '/kaggle/input/datasets/prilia/fer2013pluscleanedaugmballanced1/train'
test_dir='/kaggle/input/datasets/prilia/fer2013pluscleanedaugmballanced1/test'

print ("Versiune TensorFlow: ", tf.__version__)
print ("Versiune Keras: ", keras.__version__)

img_size=48
batch_size=64
epoci = 50
num_classes= 7 
print ("\n partea de preprocesare si impartire a datelor")
datagen = ImageDataGenerator (
    featurewise_center=False,
    featurewise_std_normalization=False,
    rescale=1./255,
    rotation_range=10,
    zoom_range= 0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.8,1.2],
    fill_mode='nearest',
    validation_split=0.20
)

test_datagen = ImageDataGenerator(rescale=1./255)

print("Setul de antrenare (80%):")
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    color_mode="grayscale",      
    batch_size=batch_size,
    class_mode='categorical',     
    shuffle=True                  
)

print("Setul de validare (20%):")
val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False,                
    subset='validation'           
)

print("Setul de testare:")
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_size, img_size),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Versiune TensorFlow:  2.19.0
# Versiune Keras:  3.10.0
#
#  partea de preprocesare si impartire a datelor
# Setul de antrenare (80%):
# Found 23251 images belonging to 7 classes.
# Setul de validare (20%):
# Found 4648 images belonging to 7 classes.
# Setul de testare:
# Found 5772 images belonging to 7 classes.

# %%
import os
import random
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array

clase_disponibile = os.listdir(train_dir)
clasa_random = random.choice(clase_disponibile)
folder_clasa = os.path.join(train_dir, clasa_random)

imagini_disponibile = os.listdir(folder_clasa)
imagine_random = random.choice(imagini_disponibile)
cale_imagine = os.path.join(folder_clasa, imagine_random)

img = load_img(cale_imagine, target_size=(img_size, img_size), color_mode="grayscale")
img_originala = img_to_array(img)

img_augmentata = datagen.random_transform(img_originala)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title(f"Original")

plt.imshow(img_originala.reshape(img_size, img_size), cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title("Augmentată")
plt.imshow(img_augmentata.reshape(img_size, img_size), cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
train_class_labels=train_generator.class_indices
print("etichete antrenament : ",train_class_labels)

val_class_labels=val_generator.class_indices
print("etichete validare : ",val_class_labels)

test_class_labels=test_generator.class_indices
print("etichete test : ",test_class_labels)
# Out:
# etichete antrenament :  {'Anger': 0, 'Disgust': 1, 'Fear': 2, 'Happy': 3, 'Neutral': 4, 'Sad': 5, 'Surprise': 6}
# etichete validare :  {'Anger': 0, 'Disgust': 1, 'Fear': 2, 'Happy': 3, 'Neutral': 4, 'Sad': 5, 'Surprise': 6}
# etichete test :  {'Anger': 0, 'Disgust': 1, 'Fear': 2, 'Happy': 3, 'Neutral': 4, 'Sad': 5, 'Surprise': 6}

# %%
#implementarea retelei de tip VRES-CNN (Dogaru & Dogaru, 2023)
import numpy as np
import tensorflow as tf
from keras.layers import (Input, SeparableConv2D, Conv2D, Activation,
                           BatchNormalization, Add, MaxPooling2D,
                           GlobalAveragePooling2D, Flatten, Dense, Dropout)
from keras.models import Model

def svcnn_resblock(x, filters, nl, resid=True, separ=True):
    csize = 3; stri = 2; psiz = 3; pad = 'same'; drop1 = 0.25

    def conv_bn_relu(inp):
        if separ:
            out = SeparableConv2D(filters, padding=pad, kernel_size=(csize, csize))(inp)
        else:
            out = Conv2D(filters, padding=pad, kernel_size=(csize, csize))(inp)
        out = BatchNormalization()(out)
        out = Activation('relu')(out)
        return out

    y = conv_bn_relu(x)
    for _ in range(nl):
        y = conv_bn_relu(y)

    if resid:
        if x.shape[-1] != filters:
            shortcut = Conv2D(filters, kernel_size=1, padding=pad)(x)
            shortcut = BatchNormalization()(shortcut)
        else:
            shortcut = x
        out = Add()([shortcut, y])
    else:
        out = y

    out = MaxPooling2D(pool_size=(psiz, psiz), strides=(stri, stri), padding=pad)(out)
    out = Dropout(drop1)(out)
    return out

def create_vres_cnn_fer(input_shape=(48, 48, 1), num_classes=7,
                         flat=0, fil=[64, 128, 256], nl=[3, 2, 2],
                         hid=[256], resid=True, separ=True):
    inputs = Input(shape=input_shape)
    t = svcnn_resblock(inputs, fil[0], nl[0], resid, separ)
    for layer in range(1, len(fil)):
        t = svcnn_resblock(t, fil[layer], nl[layer], resid, separ)

    if flat == 1:
        t = Flatten()(t)
    else:
        t = GlobalAveragePooling2D()(t)

    for units in hid:
        t = Dense(units, activation='relu')(t)
        t = Dropout(0.3)(t)

    t = Dropout(0.4)(t)
    outputs = Dense(num_classes, activation='softmax')(t)
    model = Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=5e-4),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )
    return model

print("Construim arhitectura VRES-CNN...")
with strategy.scope():
    model = create_vres_cnn_fer(
        input_shape=(48, 48, 1),
        num_classes=7,
        flat=0,
        fil=[64, 128, 256],
        nl=[3, 2, 2],
        hid=[256],
        resid=True,
        separ=True
    )

model.summary()
# Out:
# Construim arhitectura VRES-CNN...
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 48, 48, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 48, 48,    │        137 │ input_layer[0][0] │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 48, 48,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 48, 48,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 48, 48,    │      4,736 │ activation[0][0]  │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 48,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 48, 48,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 48, 48,    │      4,736 │ activation_1[0][… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 48,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 48, 48,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 48, 48,    │      4,736 │ activation_2[0][… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 48, 48,    │        128 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 48,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 48,    │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 48, 48,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 48, 48,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 24, 24,    │          0 │ add[0][0]         │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 24, 24,    │          0 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_4  │ (None, 24, 24,    │      8,896 │ dropout[0][0]     │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 24,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 24, 24,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_5  │ (None, 24, 24,    │     17,664 │ activation_4[0][… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 24,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 24, 24,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_6  │ (None, 24, 24,    │     17,664 │ activation_5[0][… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 24, 24,    │      8,320 │ dropout[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 24,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 24,    │        512 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 24, 24,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 24, 24,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 12, 12,    │          0 │ add_1[0][0]       │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 12, 12,    │          0 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_7  │ (None, 12, 12,    │     34,176 │ dropout_1[0][0]   │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 12,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 12, 12,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_8  │ (None, 12, 12,    │     68,096 │ activation_7[0][… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 12,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 12, 12,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_9  │ (None, 12, 12,    │     68,096 │ activation_8[0][… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 12, 12,    │     33,024 │ dropout_1[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 12,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 12,    │      1,024 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 12, 12,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 12, 12,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 6, 6, 256) │          0 │ add_2[0][0]       │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 6, 6, 256) │          0 │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ dropout_2[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │     65,792 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 256)       │          0 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 7)         │      1,799 │ dropout_4[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 345,424 (1.32 MB)
#  Trainable params: 341,712 (1.30 MB)
#  Non-trainable params: 3,712 (14.50 KB)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint=ModelCheckpoint(
    "v_cnn_best_model.keras",
    monitor='val_accuracy', 
    verbose=1, 
    save_best_only=True, 
    mode='max'
)

early_stopping = EarlyStopping(
    monitor='val_accuracy', 
    patience=8,               
    restore_best_weights=True,
    verbose=1
)

# %%
import time

t_start_train = time.time()
istoric_antrenare= model.fit(
    train_generator,
    epochs=epoci,
    validation_data=val_generator,
    callbacks=[checkpoint,early_stopping]
)
t_end_train = time.time()

t_start_test = time.time()
score=model.evaluate(test_generator, verbose=0)
t_end_test = time.time()

nr_total_poze= test_generator.samples

timp_antrenament_minute = int(t_end_train - t_start_train) / 60
timp_testare_secunde = t_end_test - t_start_test
latenta_ms = 1000 * timp_testare_secunde / nr_total_poze

epoci_rulate = len(istoric_antrenare.history['loss'])

print(' RAPORT DE PERFORMANȚĂ V-CNN')

print(f'Timp total antrenament ({epoci_rulate} epoci): {timp_antrenament_minute:.2f} minute')
print(f'Numărul total de parametri: {model.count_params()}')
print(f'Acuratețea finală pe setul de test: {score[1]*100:.2f} %')
print(f'Timpul total de predicție la test: {timp_testare_secunde:.4f} secunde')
print(f'Latența pe GPU (per cadru): {latenta_ms:.4f} ms')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 66 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# E0000 00:00:1776338332.451431      55 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/functional_1/dropout_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# I0000 00:00:1776338335.176716     127 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1776338335.176816     126 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.2212 - loss: 2.1412INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
#
# Epoch 1: val_accuracy improved from -inf to 0.14479, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 186s 467ms/step - accuracy: 0.2213 - loss: 2.1404 - val_accuracy: 0.1448 - val_loss: 3.8260
# Epoch 2/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.3504 - loss: 1.6448
# Epoch 2: val_accuracy improved from 0.14479 to 0.31239, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 58s 159ms/step - accuracy: 0.3504 - loss: 1.6448 - val_accuracy: 0.3124 - val_loss: 1.7392
# Epoch 3/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.4088 - loss: 1.5642
# Epoch 3: val_accuracy improved from 0.31239 to 0.43266, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 56s 155ms/step - accuracy: 0.4088 - loss: 1.5642 - val_accuracy: 0.4327 - val_loss: 1.5992
# Epoch 4/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.4540 - loss: 1.5033
# Epoch 4: val_accuracy improved from 0.43266 to 0.48903, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 51s 141ms/step - accuracy: 0.4540 - loss: 1.5033 - val_accuracy: 0.4890 - val_loss: 1.4191
# Epoch 5/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.4801 - loss: 1.4590
# Epoch 5: val_accuracy improved from 0.48903 to 0.48989, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 53s 145ms/step - accuracy: 0.4802 - loss: 1.4590 - val_accuracy: 0.4899 - val_loss: 1.4704
# Epoch 6/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.5125 - loss: 1.4273
# Epoch 6: val_accuracy improved from 0.48989 to 0.56239, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 52s 142ms/step - accuracy: 0.5125 - loss: 1.4272 - val_accuracy: 0.5624 - val_loss: 1.3263
# Epoch 7/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5527 - loss: 1.3831
# Epoch 7: val_accuracy did not improve from 0.56239
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 51s 139ms/step - accuracy: 0.5527 - loss: 1.3831 - val_accuracy: 0.5514 - val_loss: 1.3580
# Epoch 8/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5860 - loss: 1.3188
# Epoch 8: val_accuracy improved from 0.56239 to 0.58068, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 52s 142ms/step - accuracy: 0.5860 - loss: 1.3188 - val_accuracy: 0.5807 - val_loss: 1.2720
# Epoch 9/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6088 - loss: 1.2799
# Epoch 9: val_accuracy improved from 0.58068 to 0.61618, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 54s 148ms/step - accuracy: 0.6088 - loss: 1.2799 - val_accuracy: 0.6162 - val_loss: 1.2457
# Epoch 10/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6262 - loss: 1.2472
# Epoch 10: val_accuracy improved from 0.61618 to 0.66910, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 54s 147ms/step - accuracy: 0.6262 - loss: 1.2472 - val_accuracy: 0.6691 - val_loss: 1.1188
# Epoch 11/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6504 - loss: 1.2089
# Epoch 11: val_accuracy improved from 0.66910 to 0.69234, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 54s 149ms/step - accuracy: 0.6504 - loss: 1.2089 - val_accuracy: 0.6923 - val_loss: 1.0873
# Epoch 12/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6557 - loss: 1.1862
# Epoch 12: val_accuracy improved from 0.69234 to 0.73645, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 55s 150ms/step - accuracy: 0.6557 - loss: 1.1862 - val_accuracy: 0.7364 - val_loss: 0.9949
# Epoch 13/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6750 - loss: 1.1608
# Epoch 13: val_accuracy did not improve from 0.73645
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 54s
50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8178 - loss: 0.8873
# Epoch 45: val_accuracy improved from 0.86188 to 0.86446, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 52s 143ms/step - accuracy: 0.8178 - loss: 0.8873 - val_accuracy: 0.8645 - val_loss: 0.7565
# Epoch 46/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8268 - loss: 0.8747
# Epoch 46: val_accuracy did not improve from 0.86446
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 52s 142ms/step - accuracy: 0.8268 - loss: 0.8748 - val_accuracy: 0.8524 - val_loss: 0.7640
# Epoch 47/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8289 - loss: 0.8688
# Epoch 47: val_accuracy did not improve from 0.86446
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 56s 152ms/step - accuracy: 0.8289 - loss: 0.8688 - val_accuracy: 0.8442 - val_loss: 0.7988
# Epoch 48/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8273 - loss: 0.8699
# Epoch 48: val_accuracy improved from 0.86446 to 0.87435, saving model to v_cnn_best_model.keras
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 54s 148ms/step - accuracy: 0.8273 - loss: 0.8699 - val_accuracy: 0.8744 - val_loss: 0.7367
# Epoch 49/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8194 - loss: 0.8776
# Epoch 49: val_accuracy did not improve from 0.87435
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 52s 142ms/step - accuracy: 0.8194 - loss: 0.8776 - val_accuracy: 0.8731 - val_loss: 0.7377
# Epoch 50/50
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8201 - loss: 0.8762
# Epoch 50: val_accuracy did not improve from 0.87435
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 51s 140ms/step - accuracy: 0.8201 - loss: 0.8762 - val_accuracy: 0.8511 - val_loss: 0.7740
# Restoring model weights from the end of the best epoch: 48.
#  RAPORT DE PERFORMANȚĂ V-CNN
# Timp total antrenament (50 epoci): 47.00 minute
# Numărul total de parametri: 345424
# Acuratețea finală pe setul de test: 77.82 %
# Timpul total de predicție la test: 37.5346 secunde
# Latența pe GPU (per cadru): 6.5029 ms

# %%
from tensorflow.keras.models import load_model
model = load_model('v_cnn_best_model.keras') #vrescnn doar ca nu am mai schimbat eu numele . 
#am schimbat numele cand am salvat modelul pe laptop in folder

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

test_generator.reset()

print("Calculăm predicțiile pe setul de test...")
y_pred_probs = model.predict(test_generator, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_generator.classes

etichete = list(test_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='PuRd', 
            xticklabels=etichete, yticklabels=etichete)
plt.title('Matricea de Confuzie - Model V-resCNN Final')
plt.ylabel('Emoție Reală')
plt.xlabel('Emoție Prezisă')
plt.show()

print("\nRaport de Clasificare Detaliat:\n")
print(classification_report(y_true, y_pred, target_names=etichete, zero_division=0))
# Out:
# Calculăm predicțiile pe setul de test...
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step
# Raport de Clasificare Detaliat:
#
#               precision    recall  f1-score   support
#
#        Anger       0.58      0.93      0.71       828
#      Disgust       0.99      0.78      0.87       841
#         Fear       0.96      0.75      0.84       836
#        Happy       0.85      0.87      0.86       833
#      Neutral       0.69      0.72      0.71       806
#          Sad       0.77      0.55      0.64       798
#     Surprise       0.81      0.85      0.83       830
#
#     accuracy                           0.78      5772
#    macro avg       0.81      0.78      0.78      5772
# weighted avg       0.81      0.78      0.78      5772

# %%
import matplotlib.pyplot as plt


acc = istoric_antrenare.history['accuracy']
val_acc = istoric_antrenare.history['val_accuracy']
loss = istoric_antrenare.history['loss']
val_loss = istoric_antrenare.history['val_loss']

epoci_rulate = range(1, len(acc) + 1)


plt.figure(figsize=(14, 5))


plt.subplot(1, 2, 1)
plt.plot(epoci_rulate, acc, 'b-', linewidth=2, label='Antrenament')
plt.plot(epoci_rulate, val_acc, 'r-', linewidth=2, label='Validare')
plt.title('Evoluția Acurateții VresCNN', fontsize=14)
plt.xlabel('Număr Epoci', fontsize=12)
plt.ylabel('Acuratețe', fontsize=12)
plt.legend(loc='lower right')
plt.grid(True, linestyle='--', alpha=0.7)


plt.subplot(1, 2, 2)
plt.plot(epoci_rulate, loss, 'b-', linewidth=2, label='Eroare Antrenament')
plt.plot(epoci_rulate, val_loss, 'r-', linewidth=2, label='Eroare Validare')
plt.title('Scăderea Erorii (Loss) V-resCNN', fontsize=14)
plt.xlabel('Număr Epoci', fontsize=12)
plt.ylabel('Valoare Eroare', fontsize=12)
plt.legend(loc='upper right')
plt.grid(True, linestyle='--', alpha=0.7)


plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

def testeaza_cu_legenda(cale_imagine):
    
    etichete_en = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
    
    clase_ro = {
        'angry': 'FURIE',
        'disgust': 'DEZGUST',
        'fear': 'FRICĂ',
        'happy': 'FERICIRE',
        'neutral': 'NEUTRU',
        'sad': 'TRISTEȚE',
        'surprise': 'SURPRIZĂ'
    }
    
    nume_ro_scurt = ['Furie', 'Dezgust', 'Frică', 'Fericire', 'Neutru', 'Tristețe', 'Surpriză']

    try:
        img_pt_model = image.load_img(cale_imagine, target_size=(48, 48), color_mode="grayscale")
    except Exception as e:
        print(f"Eroare la încărcarea imaginii: {e}")
        return

    img_array = image.img_to_array(img_pt_model)
    img_array = np.expand_dims(img_array, axis=0) 
    img_array /= 255.0 

    predictii_brute = model.predict(img_array)[0] 
    index_maxim = np.argmax(predictii_brute)
    
    emotie_w_en = etichete_en[index_maxim]
    emotie_w_ro = clase_ro[emotie_w_en]
    procent_w = predictii_brute[index_maxim] * 100

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
    
    img_orig = cv2.imread(cale_imagine)
    if img_orig is None:
        print("Eroare: Nu am putut citi imaginea originală pentru afișare!")
        return
    img_orig = cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB)
    
    ax1.imshow(img_orig)
    ax1.axis('off') 
    
    culoare_titlu = 'green' if emotie_w_en == 'happy' else 'red' if emotie_w_en in ['angry', 'fear'] else 'darkblue'
    
    ax1.set_title(f"Rețeaua V-CNN prezice:\n{emotie_w_ro} ({procent_w:.2f}%)", 
                  fontsize=18, color=culoare_titlu, fontweight='bold', pad=20)

    y_pos = np.arange(len(nume_ro_scurt))
    procente_afisare = predictii_brute * 100
    
    bare = ax2.barh(y_pos, procente_afisare, align='center', color='skyblue', alpha=0.8)
    
    bare[index_maxim].set_color('deeppink')
    bare[index_maxim].set_alpha(1.0)

    ax2.set_yticks(y_pos)
    ax2.set_yticklabels(nume_ro_scurt, fontsize=12)
    ax2.invert_yaxis() 
    ax2.set_xlabel('Probabilitate (%)', fontsize=12)
    ax2.set_title('Distribuția detaliată a probabilităților', fontsize=14, pad=15)
    
    for i, bar in enumerate(bare):
        latime = bar.get_width()
        ax2.text(latime + 1, bar.get_y() + bar.get_height()/2, 
                 f'{procente_afisare[i]:.1f}%', 
                 va='center', fontsize=10, fontweight='bold' if i == index_maxim else 'normal')

    ax2.set_xlim(0, 110) 
    ax2.grid(axis='x', linestyle='--', alpha=0.5)

    plt.tight_layout()
    plt.show()


testeaza_cu_legenda('/kaggle/input/datasets/prilia/fer2013pluscleanedaugmballanced1/test/Anger/0_1012_Training.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step

# %%
from tensorflow.keras.models import load_model

cale_model = '/kaggle/input/datasets/mindrocrobert/modelulmeu/v_cnn_best_model (1).keras'
model = load_model(cale_model)

print("✅ SUCCES: Modelul este acum încărcat în memorie!")
# Out:
# ✅ SUCCES: Modelul este acum încărcat în memorie!
